# %%
import pandas as pd
import os
import bar_chart_race as bcr
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_past_and_projected_future_population')
df
# Out:
# [    Country (or dependent territory)     1950     1955      %     1960    %.1  \
#  0                        Afghanistan     8151     8892   1.76     9830   2.03
#  1                            Albania     1228     1393   2.56     1624   3.12
#  2                            Algeria     8893     9842   2.05    10910   2.08
#  3                     American Samoa       20       20   0.72       21   0.20
#  4                            Andorra        7        7   0.04        9   6.28
#  ..                               ...      ...      ...    ...      ...    ...
#  223                   Western Sahara       10       16  11.87       28  11.87
#  224                            Yemen     4778     5266   1.97     5872   2.20
#  225                           Zambia     2554     2870   2.36     3255   2.55
#  226                         Zimbabwe     2854     3410   3.62     4011   3.31
#  227                            World  2557629  2782099   1.70  3043002   1.81
#
# ...

# %%
df5080 = df[0]
df5080
# Out:
#     Country (or dependent territory)     1950     1955      %     1960    %.1  \
# 0                        Afghanistan     8151     8892   1.76     9830   2.03
# 1                            Albania     1228     1393   2.56     1624   3.12
# 2                            Algeria     8893     9842   2.05    10910   2.08
# 3                     American Samoa       20       20   0.72       21   0.20
# 4                            Andorra        7        7   0.04        9   6.28
# ..                               ...      ...      ...    ...      ...    ...
# 223                   Western Sahara       10       16  11.87       28  11.87
# 224                            Yemen     4778     5266   1.97     5872   2.20
# 225                           Zambia     2554     2870   2.36     3255   2.55
# 226                         Zimbabwe     2854     3410   3.62     4011   3.31
# 227                            World  2557629  2782099   1.70  3043002   1.81
#
# ...

# %%
df8515 = df[1]
df8515.reset_index(drop=True, inplace=True)
df8515
# Out:
#     Country (or dependent territory)     1985     %     1990   %.1     1995  \
# 0                        Afghanistan    13120 -2.70    13569  0.67    19446
# 1                            Albania     2957  2.05     3245  1.88     3159
# 2                            Algeria    22009  3.19    25191  2.74    28322
# 3                     American Samoa       39  3.57       48  4.09       54
# 4                            Andorra       45  5.84       53  3.41       64
# ..                               ...      ...   ...      ...   ...      ...
# 223                   Western Sahara      180  7.65      218  3.92      264
# 224                            Yemen    10540  2.91    12417  3.33    14832
# 225                           Zambia     6536  3.36     7604  3.07     8691
# 226                         Zimbabwe     8561  3.61    10157  3.48    11160
# 227                            World  4856463  1.76  5288956  1.72  5699203
#
# ...

# %%
outer_merged = pd.merge(df5080, df8515, how="inner", on='Country (or dependent territory)')
merged_df = outer_merged.drop(['%_x',
       '%.1_x', '%.2_x', '%.3_x', '%.4_x',
       '%.5_x', '%_y', '%.1_y', '%.2_y',
       '%.3_y', '%.4_y', '%.5_y', '%.6'], axis=1)
merged_df.reset_index(drop=True, inplace= True)
sorted_df = merged_df.sort_values(by="1950",ascending=False,kind="mergesort")
finaldf = sorted_df.transpose()
file_name = 'populationworkbook.csv'
finaldf.to_csv(file_name)

# %%
merged_df.sort_values(by="1950",ascending=False,kind="mergesort")
# Out:
#     Country (or dependent territory)     1950     1955     1960     1965  \
# 227                            World  2557629  2782099  3043002  3350426
# 41                             China   562580   607047   651340   716667
# 90                             India   369881   404268   445394   494964
# 215                    United States   151869   165070   179980   193527
# 165                           Russia   101937   111126   119632   126542
# ..                               ...      ...      ...      ...      ...
# 210                           Tuvalu        5        5        6        6
# 138                            Nauru        4        4        5        6
# 167                 Saint Barthélemy        3        3        3        3
# 171                     Saint Martin        3        4        5        5
# 183                     Sint Maarten        3        3        3        5
#
#         1970     1975     1980     1985     1990     1995     2000     2005  \
# ...

# %%
df3 = pd.read_csv(file_name)

# %%
df4 = df3.iloc[: ,:]
df4
# Out:
#                           Unnamed: 0      227       41       90  \
# 0   Country (or dependent territory)    World    China    India
# 1                               1950  2557629   562580   369881
# 2                               1955  2782099   607047   404268
# 3                               1960  3043002   651340   445394
# 4                               1965  3350426   716667   494964
# 5                               1970  3712698   822116   553889
# 6                               1975  4089084   920295   618923
# 7                               1980  4451363   987822   684888
# 8                               1985  4856463  1061876   759613
# 9                               1990  5288956  1153164   838159
# 10                              1995  5699203  1221056   920585
# 11                              2000  6088572  1268302  1006301
# 12                              2005  6473045  1302285  1090974
# 13                              2010  6866333  1336681  1173109
# ...

# %%
df4.columns = df4.loc[0,:]
df4.drop(0,axis=0,inplace=True)
df4
# Out:
# 0  Country (or dependent territory)    World    China    India United States  \
# 1                              1950  2557629   562580   369881        151869
# 2                              1955  2782099   607047   404268        165070
# 3                              1960  3043002   651340   445394        179980
# 4                              1965  3350426   716667   494964        193527
# 5                              1970  3712698   822116   553889        203985
# 6                              1975  4089084   920295   618923        215466
# 7                              1980  4451363   987822   684888        227225
# 8                              1985  4856463  1061876   759613        237924
# 9                              1990  5288956  1153164   838159        249623
# 10                             1995  5699203  1221056   920585        266279
# 11                             2000  6088572  1268302  1006301        282163
# ...

# %%
df4.rename(columns={'Country (or dependent territory)':'Date'}, inplace=True)
df4
# Out:
# 0   Date    World    China    India United States  Russia   Japan Indonesia  \
# 1   1950  2557629   562580   369881        151869  101937   83806     82979
# 2   1955  2782099   607047   404268        165070  111126   89816     90255
# 3   1960  3043002   651340   445394        179980  119632   94092    100146
# 4   1965  3350426   716667   494964        193527  126542   98883    110754
# 5   1970  3712698   822116   553889        203985  130246  104345    122292
# 6   1975  4089084   920295   618923        215466  134294  111574    135214
# 7   1980  4451363   987822   684888        227225  139039  116808    150322
# 8   1985  4856463  1061876   759613        237924  143938  120755    166070
# 9   1990  5288956  1153164   838159        249623  147973  123538    181600
# 10  1995  5699203  1221056   920585        266279  148759  125328    197604
# 11  2000  6088572  1268302  1006301        282163  147054  126776    214091
# ...

# %%
df4.set_index('Date', inplace=True)

# %%
df4.index
# Out:
# Index(['1950', '1955', '1960', '1965', '1970', '1975', '1980', '1985', '1990',
#        '1995', '2000', '2005', '2010', '2015'],
#       dtype='object', name='Date')

# %%
df4
# Out:
# 0       World    China    India United States  Russia   Japan Indonesia  \
# Date
# 1950  2557629   562580   369881        151869  101937   83806     82979
# 1955  2782099   607047   404268        165070  111126   89816     90255
# 1960  3043002   651340   445394        179980  119632   94092    100146
# 1965  3350426   716667   494964        193527  126542   98883    110754
# 1970  3712698   822116   553889        203985  130246  104345    122292
# 1975  4089084   920295   618923        215466  134294  111574    135214
# 1980  4451363   987822   684888        227225  139039  116808    150322
# 1985  4856463  1061876   759613        237924  143938  120755    166070
# 1990  5288956  1153164   838159        249623  147973  123538    181600
# 1995  5699203  1221056   920585        266279  148759  125328    197604
# 2000  6088572  1268302  1006301        282163  147054  126776    214091
# 2005  6473045  1302285  1090974        295517  143320  127716    229245
# ...

# %%
df4.to_csv('worldPopulation.csv')

# %%
df5 = pd.read_csv('worldPopulation.csv')

# %%
df5['Date'] = pd.to_datetime(df5['Date'].astype(str), format='%Y')
df5
# Out:
#          Date    World    China    India  United States  Russia   Japan  \
# 0  1950-01-01  2557629   562580   369881         151869  101937   83806
# 1  1955-01-01  2782099   607047   404268         165070  111126   89816
# 2  1960-01-01  3043002   651340   445394         179980  119632   94092
# 3  1965-01-01  3350426   716667   494964         193527  126542   98883
# 4  1970-01-01  3712698   822116   553889         203985  130246  104345
# 5  1975-01-01  4089084   920295   618923         215466  134294  111574
# 6  1980-01-01  4451363   987822   684888         227225  139039  116808
# 7  1985-01-01  4856463  1061876   759613         237924  143938  120755
# 8  1990-01-01  5288956  1153164   838159         249623  147973  123538
# 9  1995-01-01  5699203  1221056   920585         266279  148759  125328
# 10 2000-01-01  6088572  1268302  1006301         282163  147054  126776
# 11 2005-01-01  6473045  1302285  1090974         295517  143320  127716
# ...

# %%
def summary(values, ranks):
    population = int(round(values.sum(), -2))
    s = f'TOTAL POPULATION - {population:,.0f}'
    return {'x': .99, 'y': .05, 's': s, 'ha': 'right', 'size': 8}

# %%
df5.set_index('Date', inplace=True)
df5
# Out:
#               World    China    India  United States  Russia   Japan  \
# Date
# 1950-01-01  2557629   562580   369881         151869  101937   83806
# 1955-01-01  2782099   607047   404268         165070  111126   89816
# 1960-01-01  3043002   651340   445394         179980  119632   94092
# 1965-01-01  3350426   716667   494964         193527  126542   98883
# 1970-01-01  3712698   822116   553889         203985  130246  104345
# 1975-01-01  4089084   920295   618923         215466  134294  111574
# 1980-01-01  4451363   987822   684888         227225  139039  116808
# 1985-01-01  4856463  1061876   759613         237924  143938  120755
# 1990-01-01  5288956  1153164   838159         249623  147973  123538
# 1995-01-01  5699203  1221056   920585         266279  148759  125328
# 2000-01-01  6088572  1268302  1006301         282163  147054  126776
# 2005-01-01  6473045  1302285  1090974         295517  143320  127716
# ...

# %%
bcr.bar_chart_race(df=df5, n_bars=27, filter_column_colors=True, bar_size=0.6, 
                   title='Population by Country per Year', interpolate_period=True,
                   title_size='small', fixed_max=True, bar_label_size=4,
                   steps_per_period=9, period_length=420, perpendicular_bar_func='mean')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 127 () missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# C:\ProgramData\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# C:\ProgramData\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# C:\ProgramData\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 130 (\x82) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# C:\ProgramData\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 131 (\x83) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# ...

# %%
df6 = df5.copy()
df6
# Out:
#               World    China    India  United States  Russia   Japan  \
# Date
# 1950-01-01  2557629   562580   369881         151869  101937   83806
# 1955-01-01  2782099   607047   404268         165070  111126   89816
# 1960-01-01  3043002   651340   445394         179980  119632   94092
# 1965-01-01  3350426   716667   494964         193527  126542   98883
# 1970-01-01  3712698   822116   553889         203985  130246  104345
# 1975-01-01  4089084   920295   618923         215466  134294  111574
# 1980-01-01  4451363   987822   684888         227225  139039  116808
# 1985-01-01  4856463  1061876   759613         237924  143938  120755
# 1990-01-01  5288956  1153164   838159         249623  147973  123538
# 1995-01-01  5699203  1221056   920585         266279  148759  125328
# 2000-01-01  6088572  1268302  1006301         282163  147054  126776
# 2005-01-01  6473045  1302285  1090974         295517  143320  127716
# ...

# %%
df6.drop('World', axis=1, inplace=True)
df6
# Out:
#               China    India  United States  Russia   Japan  Indonesia  \
# Date
# 1950-01-01   562580   369881         151869  101937   83806      82979
# 1955-01-01   607047   404268         165070  111126   89816      90255
# 1960-01-01   651340   445394         179980  119632   94092     100146
# 1965-01-01   716667   494964         193527  126542   98883     110754
# 1970-01-01   822116   553889         203985  130246  104345     122292
# 1975-01-01   920295   618923         215466  134294  111574     135214
# 1980-01-01   987822   684888         227225  139039  116808     150322
# 1985-01-01  1061876   759613         237924  143938  120755     166070
# 1990-01-01  1153164   838159         249623  147973  123538     181600
# 1995-01-01  1221056   920585         266279  148759  125328     197604
# 2000-01-01  1268302  1006301         282163  147054  126776     214091
# 2005-01-01  1302285  1090974         295517  143320  127716     229245
# ...

# %%
bcr.bar_chart_race(df=df6, n_bars=27, filter_column_colors=True, bar_size=0.6, 
                   title='Population by Country per Year', interpolate_period=True,
                   title_size='small', fixed_max=True, bar_label_size=4,
                  steps_per_period=9, period_length=420, perpendicular_bar_func='mean', period_summary_func=summary)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 127 () missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# C:\ProgramData\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# C:\ProgramData\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# C:\ProgramData\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 130 (\x82) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# C:\ProgramData\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 131 (\x83) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# ...
